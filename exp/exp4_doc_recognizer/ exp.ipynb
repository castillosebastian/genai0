# %% [markdown]
# # Revisión Azure DI vs. Langchain+Unstructured+OpenAI
# ## Tablas Financieras del Reporte de Tesla 10-K 2022

# %% [markdown]
# Se trabajó con un pdf que incluye la información financiara tabulada del reporte 10K de Testa ([link](https://github.com/castillosebastian/genai0/blob/main/exp/exp4_doc_recognizer/Tesla_10k_short.pdf))

# %% [markdown]
# Importamos librerías

# %%
import polars as pl
import pandas as pd
import json
import os
import openai
from langchain.embeddings import AzureOpenAIEmbeddings
from langchain.chat_models import AzureChatOpenAI
from langchain.schema import HumanMessage
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import uuid
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.storage import InMemoryStore
from langchain.vectorstores import Chroma
from langchain_core.documents import Document
import time
from typing import Any
from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Azure Document Intelligence
#
# Procesamos el documento con la API de Azure Doc-Intelligence, siguiendo este [script](https://github.com/castillosebastian/genai0/blob/main/exp/exp4_doc_recognizer/exp.py) (basado en el de Azure [ver aquí](https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/quickstarts/get-started-sdks-rest-api?view=doc-intel-4.0.0&pivots=programming-language-python)).

# %% [markdown]
# ### Balance Sheet 2022 (10-K)

# %%
balance_sheet = pd.read_csv('balance_sheet.csv')
balance_sheet = balance_sheet.replace('\n', '', regex=True)
balance_sheet
# Out:
#                                                     0                 1  \
# 0                                                 NaN  December 31,2022
# 1                                              Assets               NaN
# 2                                      Current assets               NaN
# 3                           Cash and cash equivalents           $16,253
# 4                              Short-term investments             5,932
# 5                            Accounts receivable, net             2,952
# 6                                           Inventory            12,839
# 7           Prepaid expenses and other current assets             2,941
# 8                                Total current assets            40,917
# 9                       Operating lease vehicles, net             5,035
# 10                          Solar energy systems, net             5,489
# 11                 Property, plant and equipment, net            23,548
# 12                Operating lease right-of-use assets             2,563
# 13                                Digital assets, net               184
# 14                             Intangible assets, net               215
# 15                                           Goodwill               194
# 16                           Other non-current assets             4,193
# 17                                       Total assets           $82,338
# 18                                        Liabilities               NaN
# 19                                Current liabilities               NaN
# 20                                   Accounts payable           $15,255
# 21                      Accrued liabilities and other             7,142
# 22                                   Deferred revenue             1,747
# 23                                  Customer deposits             1,063
# 24         Current portion of debt and finance leases             1,502
# 25                          Total current liabilities            26,709
# 26    Debt and finance leases, net of current portion             1,597
# 27           Deferred revenue, net of current portion             2,804
# 28                        Other long-term liabilities             5,330
# 29                                  Total liabilities            36,440
# 30            Commitments and contingencies (Note 15)               NaN
# 31  Redeemable noncontrolling interests in subsidi...               409
# 32                                             Equity               NaN
# 33                               Stockholders' equity               NaN
# 34  Preferred stock; $0.001 par value; 100 shares ...                 —
# 35  Common stock; $0.001 par value; 6,000 shares a...                 3
# 36                         Additional paid-in capital            32,177
# 37      Accumulated other comprehensive (loss) income             (361)
# 38                              Retained earnings (1)            12,885
# 39                         Total stockholders' equity            44,704
# 40           Noncontrolling interests in subsidiaries               785
# 41                       Total liabilities and equity           $82,338
#
#                    2
# 0   December 31,2021
# 1                NaN
# 2                NaN
# 3            $17,576
# 4                131
# 5              1,913
# 6              5,757
# 7              1,723
# 8             27,100
# 9              4,511
# 10             5,765
# 11            18,884
# 12             2,016
# 13             1,260
# 14               257
# 15               200
# 16             2,138
# 17           $62,131
# 18               NaN
# 19               NaN
# 20           $10,025
# 21             5,719
# 22             1,447
# 23               925
# 24             1,589
# 25            19,705
# 26             5,245
# 27             2,052
# 28             3,546
# 29            30,548
# 30               NaN
# 31               568
# 32               NaN
# 33               NaN
# 34                 —
# 35                 3
# 36            29,803
# 37                54
# 38               329
# 39            30,189
# 40               826
# 41           $62,131

# %% [markdown]
# **Obaservación**: No contiene errores. Necesita posprocesamiento para pasar al LLM.

# %% [markdown]
# ### Income Statement 2022 (10-K)

# %%
statement_operation = pd.read_csv('statement_operation.csv')
statement_operation = statement_operation.replace('\n', '', regex=True)
statement_operation
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                2022
# 2                                            Revenues
# 3                                    Automotive sales
# 4                       Automotive regulatory credits
# 5                                  Automotive leasing
# 6                           Total automotive revenues
# 7                       Energy generation and storage
# 8                                  Services and other
# 9                                      Total revenues
# 10                                   Cost of revenues
# 11                                   Automotive sales
# 12                                 Automotive leasing
# 13                  Total automotive cost of revenues
# 14                      Energy generation and storage
# 15                                 Services and other
# 16                             Total cost of revenues
# 17                                       Gross profit
# 18                                 Operating expenses
# 19                           Research and development
# 20                Selling, general and administrative
# 21                            Restructuring and other
# 22                           Total operating expenses
# 23                             Income from operations
# 24                                    Interest income
# 25                                   Interest expense
# 26                        Other (expense) income, net
# 27                         Income before income taxes
# 28                         Provision for income taxes
# 29                                         Net income
# 30  Net income attributable to noncontrollinginter...
# 31     Net income attributable to common stockholders
# 32                                                NaN
# 33  Net income per share of common stockattributab...
# 34                                              Basic
# 35                                            Diluted
# 36  Weighted average shares used in computing neti...
# 37                                              Basic
# 38                                            Diluted
#
#                           1        2        3
# 0   Year Ended December 31,      NaN      NaN
# 1                      2021     2020      NaN
# 2                       NaN      NaN      NaN
# 3                   $67,210  $44,125  $24,604
# 4                     1,776    1,465    1,580
# 5                     2,476    1,642    1,052
# 6                    71,462   47,232   27,236
# 7                     3,909    2,789    1,994
# 8                     6,091    3,802    2,306
# 9                    81,462   53,823   31,536
# 10                      NaN      NaN      NaN
# 11                   49,599   32,415   19,696
# 12                    1,509      978      563
# 13                   51,108   33,393   20,259
# 14                    3,621    2,918    1,976
# 15                    5,880    3,906    2,671
# 16                   60,609   40,217   24,906
# 17                   20,853   13,606    6,630
# 18                      NaN      NaN      NaN
# 19                    3,075    2,593    1,491
# 20                    3,946    4,517    3,145
# 21                      176     (27)        —
# 22                    7,197    7,083    4,636
# 23                   13,656    6,523    1,994
# 24                      297       56       30
# 25                   (191 )   (371 )    (748)
# 26                     (43)      135    (122)
# 27                   13,719    6,343    1,154
# 28                    1,132      699      292
# 29                   12,587    5,644      862
# 30                       31      125      141
# 31                  $12,556   $5,519     $721
# 32                      NaN      NaN      NaN
# 33                      NaN      NaN      NaN
# 34                    $4.02    $1.87    $0.25
# 35                    $3.62    $1.63    $0.21
# 36                      NaN      NaN      NaN
# 37                    3,130    2,959    2,798
# 38                    3,475    3,386    3,249

# %% [markdown]
# **Observación**: veo que las columnas necesitan pos-procesamiento. Por ejemplo el fila 1 tiene celdas desplazadas, que son importantes pues refieren a los años!

# %% [markdown]
# # Langchain + Unstructured  + OpenAI

# %%
elements = partition_pdf(filename='Tesla_10k_short.pdf', infer_table_structure=True)
tables = [el for el in elements if el.category == "Table"]
print(tables[0].text)
# Out:
# December31, 2022 December31, 2021 Cashandcashequivalents Short-terminvestments Accountsreceivable,net Inventory Prepaidexpensesandothercurrentassets Totalcurrentassets $ 16,253 $ 5,932 2,952 12,839 2,941 40,917 5,035 5,489 23,548 2,563 184 215 194 4,193 82,338 $ Totalassets $ Accountspayable Accruedliabilitiesandother Deferredrevenue Customerdeposits Currentportionofdebtandfinanceleases Totalcurrentliabilities $ 15,255 $ 7,142 1,747 1,063 1,502 26,709 1,597 2,804 5,330 36,440 Totalliabilities 409 Preferredstock;$0.001parvalue;100sharesauthorized; nosharesissuedandoutstanding Commonstock;$0.001parvalue;6,000sharesauthorized; 3,164and3,100sharesissuedandoutstandingasof December31,2022andDecember31,2021,respectively(1) Additionalpaid-incapital — 3 32,177 Accumulatedothercomprehensive(loss)income Retainedearnings(1) Totalstockholders’equity Totalliabilitiesandequity $ (361 ) 12,885 44,704 785 82,338 $

# %%
print(tables[0].metadata.text_as_html)
# Out:
# <table><thead><th rowspan="2">sets</th><th>December 31, 2022</th><th colspan="2">December 31, 2021</th></thead><thead><th></th><th></th><th></th><th></th></thead><tr><td>irrent assets</td><td></td><td></td><td></td></tr><tr><td>Cash and cash equivalents</td><td>16,253</td><td>$</td><td>17,576</td></tr><tr><td>Short-term investments</td><td>5,932</td><td></td><td>131</td></tr><tr><td>Accounts receivable, net</td><td>2,952</td><td></td><td>1,913</td></tr><tr><td>Inventory</td><td>12,839</td><td></td><td>5,757</td></tr><tr><td>Prepaid expenses and other current assets</td><td>2,941</td><td></td><td>1,723</td></tr><tr><td>Total current assets</td><td>40,917</td><td></td><td>27,100</td></tr><tr><td>yerating lease vehicles, net</td><td>5,035</td><td></td><td>4,511</td></tr><tr><td>lar energy systems, net</td><td>5,489</td><td></td><td>5,765</td></tr><tr><td>operty, plant and equipment, net</td><td>23,548</td><td></td><td>18,884</td></tr><tr><td>lease</td><td></td><td></td><td></td></tr><tr><td>yerating right-of-use assets</td><td>2,563</td><td></td><td>2,016</td></tr><tr><td>gital assets, net</td><td>184</td><td></td><td>1,260</td></tr><tr><td>tangible assets, net</td><td>215</td><td></td><td>257</td></tr><tr><td>odwill</td><td>194</td><td></td><td>200</td></tr><tr><td>her non-current assets</td><td>4,193</td><td></td><td>2,138</td></tr><tr><td>Total assets</td><td>82,338</td><td>$</td><td>62,131</td></tr><tr><td colspan="4">abilities</td></tr><tr><td colspan="4">irrent liabilities</td></tr><tr><td>Accounts payable</td><td>15,255</td><td>$</td><td>10,025</td></tr><tr><td>Accrued liabilities and other</td><td>7,142</td><td></td><td>5,719</td></tr><tr><td>Deferred revenue</td><td>1,747</td><td></td><td>1,447</td></tr><tr><td>Customer</td><td></td><td></td><td>925</td></tr><tr><td>deposits</td><td>1,063</td><td></td><td></td></tr><tr><td>Current portion of debt and finance leases</td><td>1,502</td><td></td><td>1,589</td></tr><tr><td>Total current liabilities</td><td>26,709</td><td></td><td>19,705</td></tr><tr><td>»bt and finance leases, net of current portion</td><td>1,597</td><td></td><td>5,245</td></tr><tr><td>ferred revenue, net of current portion</td><td>2,804</td><td></td><td>2,052</td></tr><tr><td>her long-term liabilities</td><td>5,330</td><td></td><td>3,546</td></tr><tr><td>Total liabilities</td><td>36,440</td><td></td><td>30,548</td></tr><tr><td colspan="4">ymmitments and contingencies (Note 15)</td></tr><tr><td colspan="4">»&gt;deemable noncontrolling interests in subsidiaries 409 568</td></tr><tr><td>juity</td><td></td><td></td><td></td></tr><tr><td>ockholders’ equity</td><td></td><td></td><td></td></tr><tr><td colspan="4">Preferred stock; $0.001 par value; 100 shares authorized;</td></tr><tr><td colspan="4">no shares issued and outstanding</td></tr><tr><td colspan="4">Common stock; $0.001 par value; 6,000 shares authorized; and shares issued and of</td></tr><tr><td colspan="4">3,164 3,100 outstanding as December 31, 2022 and December 31, 2021, respectively (1)</td></tr><tr><td>Additional paid-in capital</td><td>32,177</td><td></td><td>29,803</td></tr><tr><td>Accumulated other comprehensive (loss) income</td><td>(361)</td><td></td><td>54</td></tr><tr><td>Retained earnings (1)</td><td>12,885</td><td></td><td>329</td></tr><tr><td>Total stockholders’ equity</td><td>44,704</td><td></td><td>30,189</td></tr><tr><td>mncontrolling interests in subsidiaries</td><td>785</td><td></td><td>826</td></tr><tr><td>Total liabilities and equity</td><td>82,338</td><td>$</td><td>62,131</td></tr></table>

# %%
balance_sheet_text = tables[0].text
balance_sheet_html = tables[0].metadata.text_as_html

# %%
def llm():
    return AzureChatOpenAI(model_name="gtp35turbo-latest")

model = llm()

message = HumanMessage(
    content= f'You are a financial assistant, convert this html table related to 10-k report in tabular format in simple text: "{balance_sheet_html}". Only return the text'
)

html_result = model([message])

# %%
print(html_result.content)
# Out:
# sets  December 31, 2022  December 31, 2021
# irrent assets           16,253              $             17,576
# Cash and cash equivalents            5,932                                131
# Short-term investments            2,952                                1,913
# Accounts receivable, net           12,839                               5,757
# Inventory           2,941                                1,723
# Total current assets           40,917                               27,100
# yerating lease vehicles, net           5,035                                4,511
# lar energy systems, net           5,489                                5,765
# operty, plant and equipment, net           23,548                               18,884
# lease
# yerating right-of-use assets           2,563                                2,016
# gital assets, net           184                                1,260
# tangible assets, net           215                                257
# odwill           194                                200
# her non-current assets           4,193                                2,138
# Total assets           82,338              $             62,131
# abilities
# irrent liabilities
# Accounts payable           15,255              $             10,025
# Accrued liabilities and other           7,142                                5,719
# Deferred revenue           1,747                                1,447
# Customer                                           925
# deposits           1,063
# Current portion of debt and finance leases           1,502                                1,589
# Total current liabilities           26,709                               19,705
# »bt and finance leases, net of current portion           1,597                                5,245
# ferred revenue, net of current portion           2,804                                2,052
# her long-term liabilities           5,330                                3,546
# Total liabilities           36,440                               30,548
# ymmitments and contingencies (Note 15)
# »&gt;deemable noncontrolling interests in subsidiaries 409 568
# juity
# ockholders’ equity
# Preferred stock; $0.001 par value; 100 shares authorized;
# no shares issued and outstanding
# Common stock; $0.001 par value; 6,000 shares authorized; and shares issued and of
# 3,164 3,100 outstanding as December 31, 2022 and December 31, 2021, respectively (1)
# Additional paid-in capital           32,177                                29,803
# Accumulated other comprehensive (loss) income           (361)                                54
# Retained earnings (1)           12,885                                329
# Total stockholders’ equity           44,704                               30,189
# mncontrolling interests in subsidiaries           785                                826
# Total liabilities and equity           82,338              $             62,131

# %%
message = HumanMessage(
    content= f'You are an assistant tasked with summarizing tables. Give a concise summary of Tesla Balance Sheet: {html_result.content}'
)

summary = model([message])

# %%
print(summary.content)
# Out:
# The Tesla balance sheet as of December 31, 2022, and December 31, 2021, shows the following key figures:
# - Current assets decreased from $17,576 million in 2021 to $16,253 million in 2022.
# - Cash and cash equivalents significantly increased from $131 million in 2021 to $5,932 million in 2022.
# - Short-term investments also increased from $1,913 million in 2021 to $2,952 million in 2022.
# - Accounts receivable, net increased from $5,757 million in 2021 to $12,839 million in 2022.
# - Inventory increased from $1,723 million in 2021 to $2,941 million in 2022.
# - Total current assets increased from $27,100 million in 2021 to $40,917 million in 2022.
# - Property, plant, and equipment, net increased from $18,884 million in 2021 to $23,548 million in 2022.
# - Total assets increased from $62,131 million in 2021 to $82,338 million in 2022.
# - Current liabilities increased from $19,705 million in 2021 to $26,709 million in 2022.
# - Long-term debt and finance leases decreased from $5,245 million in 2021 to $1,597 million in 2022.
# - Total liabilities increased from $30,548 million in 2021 to $36,440 million in 2022.
# - Stockholders' equity increased from $30,189 million in 2021 to $44,704 million in 2022.
# - Total liabilities and equity increased from $62,131 million in 2021 to $82,338 million in 2022.

# %% [markdown]
# # Conclusion
#
# | Tecnología                        | Estado                          | Observaciones |
# |-----------------------------------|---------------------------------|---------------|
# | Document Intelligence-Azure       | ✅+, con errores no críticos.   | Mejor Desempeño Document Intelligence: se puede reconocer y estructurar información, con un elevado grado de eficacia. Los errores de tabulado requieren de posprocesamiento. |
# | Langchain-Unstructured-OpenAI     | ✅-, con errores no críticos.   | Langchain + Unstructured + OpenAI: se puede reconocer y estructurar información. La implementación funciona solo cuando el pre-procesamiento convierte el pdf en html. Cuando se convertía a texto perdía la estructura. Requiere prompt-engineering.
